# %% [markdown]
# # TP4 : Paramètres et robustesse des méthodes de réduction de dimension
#
# Ce TP vise à étudier l'influence des paramètres sur la robustesse des méthodes de réduction de dimension (Isomap, Diffusion Maps, t-SNE).

# %% [markdown]
# ## Objectifs
# - Tester différents paramètres pour chaque méthode
# - Évaluer la robustesse face au bruit et aux données incomplètes
# - Visualiser et comparer les résultats

# %% [markdown]
# ## Consignes
# 1. Appliquer Isomap sur un jeu de données (Swiss Roll ou MNIST) avec différents k (nombre de voisins).
# 2. Appliquer Diffusion Maps avec différents paramètres (epsilon, t).
# 3. Appliquer t-SNE avec différentes valeurs de perplexité et learning rate.
# 4. Ajouter du bruit ou retirer des points et observer l'impact sur les résultats.
# 5. Comparer la robustesse des méthodes.

# %%
# 1. Appliquer Isomap avec différents k
# (À compléter)

# %%
# 2. Appliquer Diffusion Maps avec différents paramètres
# (À compléter)

# %%
# 3. Appliquer t-SNE avec différentes valeurs de perplexité et learning rate
# (À compléter)

# %%
# 4. Ajouter du bruit ou retirer des points et observer l'impact
# (À compléter)

# %% [markdown]
# ## Analyse et comparaison
# - Comparez la robustesse des méthodes selon les paramètres et la qualité des données.
