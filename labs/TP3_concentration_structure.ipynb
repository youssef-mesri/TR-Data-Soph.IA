# %% [markdown]
# # TP3 : Étude de la concentration des distances en haute dimension
#
# Ce TP vise à illustrer la malédiction de la dimension et la concentration des distances dans des espaces de grande dimension.

# %% [markdown]
# ## Objectifs
# - Simuler des points dans des espaces de différentes dimensions
# - Calculer les distances moyennes et écarts-types
# - Visualiser la concentration des distances quand la dimension augmente

# %% [markdown]
# ## Consignes
# 1. Simuler des points uniformément dans $[0,1]^d$ pour plusieurs valeurs de $d$ (ex : 2, 5, 10, 50, 100).
# 2. Calculer la distance euclidienne entre tous les couples de points.
# 3. Calculer la moyenne et l'écart-type des distances pour chaque dimension.
# 4. Visualiser l'évolution du rapport écart-type/moyenne en fonction de la dimension.

# %%
# 1. Simuler des points dans [0,1]^d pour plusieurs valeurs de d
# (À compléter)

# %%
# 2. Calculer les distances euclidiennes entre tous les couples de points
# (À compléter)

# %%
# 3. Calculer la moyenne et l'écart-type des distances pour chaque dimension
# (À compléter)

# %%
# 4. Visualiser l'évolution du rapport écart-type/moyenne
# (À compléter)

# %% [markdown]
# ## Analyse et interprétation
# - Que constatez-vous lorsque la dimension augmente ?
# - Expliquez le phénomène de concentration des distances.
